# %%
from google.colab import drive
drive.mount('/content/gdrive')

# %%
# %cd gdrive/My Drive/
# %cd Algorithm

# %%
# !git init

# %%
# !git add .
# !git commit -m '#3, #771 solved some hash function problems'

# %%
# !git config --global user.email "youwjune@gmail.com"
# !git config --global user.name "wonjunYou"

# %%
# !git remote add origin "https://wonjunYou:youww83636427!@github.com/wonjunYou/Algorithm.git"
# !git remote

# %%
# !git remote rm origin

# %%
# !git pull origin master

# %%
# !git push origin master
