# %%
def getSolutionList(n):
    solutionList[0]=1
    solutionList[1]=2
    for i in range(2,n):
        solutionList[i] = solutionList[i-1] + solutionList[i-2]
    return solutionList[n-1]
        
n= int(input())
solutionList = [0]*n
print(getSolutionList(n))
# Out:
# 3
# 3

# %%
p = [20,10,5,10]
f= [3,0,0,0]

score = [0]*(len(p)+1)
n = len(p)
jump = 0

for i in range(n-1, -1 ,-1):
    tmp = p[i]
    
    if(f[i]+i+1 < n):
        tmp = tmp+score[f[i]+i+1]
        jump = score[i+1]
    
    score[i]= max(tmp,jump)

print("누적 최고 점수는",score[0])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-17-46a4d4c70a6d> in <module>
#      11     if(f[i]+i+1 < n):
#      12         tmp = tmp+score[f[i]+i+1]
# ---> 13         jump = tmp[i+1]
#      14
#      15     score[i]= max(tmp,jump)
#
# TypeError: 'int' object is not subscriptable
