# %%
#Stack in Python

stack = []
stack.append(5)
stack.append(2)
stack.append(3)
stack.append(7)
stack.pop()
stack.append(1)
stack.append(4)
stack.pop()
# Out:
# 4

# %%
#Queue in Python

from collections import deque

queue = deque()

queue.append(5)
queue.append(2)
queue.append(3)
queue.append(7)
queue.popleft()
queue.append(1)
queue.append(4)
queue.popleft()

print(queue)
queue.reverse()
print(queue)
# Out:
# deque([3, 7, 1, 4])
# deque([4, 1, 7, 3])

# %%
#1.DFS: implemented by stack
'''
Sequence
1. 탐색 시작 노드를 스택에 삽입하고 visited[v] = true 처리
2. 스택의 최상단 노드에 
1)방문하지 않은 인접한 노드가 하나라도 있으면 
그 노드를 스택에 넣고 visited[v] = true.
2) 다 visited[v] = true 인 경우, 자기 자신(최상단) pop
3. Stack의 최상단 노드가 아무것도 없을 때까지 반복한다.
'''

def dfs(graph,v,visited):
    #현재 노드를 방문 처리
    visited[v] = True
    print(v, end=' ')
    #현재 노드와 연결된 다른 노드를 재귀적으로 방문
    for i in graph[v]:
        if(not visited[i]):
            dfs(graph,i,visited)

graph = [
    [],
    [2,3,8],
    [1,7],
    [1,4,5],
    [3,5],
    [3,4],
    [7],
    [2,6,8],
    [1,7]
]

#각 노드가 방문한 정보를 표현. 단 index = 0 을 사용하지 않기 위해서
#visited의 크기도 8+1인 9로 설정
visited = [False] * 9

dfs(graph, 1, visited)
# Out:
# 1 2 7 6 8 3 4 5

# %%
#2. BFS: implemented by Queue
'''
Sequence
1. 탐색 시작 노드를 큐에 삽입하고 visitied[v] = true 처리
2. 큐에서 노드를 꺼낸 뒤에 해당 노드의 인접 노드 중에서 방문하지 않는 노드를 
모두 큐에 삽입하고 방문 처리한다.
3. 더이상 큐에 아무 것도 남아 있지 않을 때까지 반복한다.
'''

from collections import deque

#BFS 메서드 정의

def bfs(graph, start, visited):
    #큐 구현을 위해 deque 라이브러리 사용
    queue = deque([start])
    #현재 노드를 방문 처리
    visited[start] = True
    while queue:
        v = queue.popleft()
        print(v, end=' ')
        
        #아직 방문하지 않은 요소들을 큐에 삽입
        for i in graph[v]:
            if not visited[i]:
                queue.append(i)
                visited[i] = True
                
        
graph = [
    [],
    [2,3,8],
    [1,7],
    [1,4,5],
    [3,5],
    [3,4],
    [7],
    [2,6,8],
    [1,7]
]

#각 노드가 방문한 정보를 표현. 단 index = 0 을 사용하지 않기 위해서
#visited의 크기도 8+1인 9로 설정
visited = [False] * 9

bfs(graph, 1, visited)
# Out:
# 1 2 3 8 7 4 5 6

# %%
#음료수 얼려 먹기

def dfs(x,y):
    if(x<= -1 or x>=n or y<=1 or y>=m):
        return false
    
    if graph[x][y] ==0:
        graph[x][y] =1
        dfs(x-1,y)
        dfs(x,y-1)
        dfs(x+1,y)
        dfs(x,y+1)
        return True
    return False

n,m = map(int, input().split())

graph = []
for i in range(n):
    graph.append(list(map(int,input())))
    
result = 0
for i in range(n):
    for j in range(m):
        #True값때만 result +1
        if dfs(i,j) == True:
            result +=1
print(result)
# Out:
# 5
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-9-2b66dee53d0b> in <module>
#      14     return False
#      15
# ---> 16 n,m = map(int, input().split())
#      17
#      18 graph = []
#
# ValueError: not enough values to unpack (expected 2, got 1)

# %%
#미로 탈출 N X M
#처음 방문하는 경우에만 +1
#벽인 경우, 공간을 벗어난 경우 continue문 처리를 통해서 무시한다.

def bfs(x,y):
    #큐 구현을 위해 deque 라이브러리 사용
    queue = deque()
    queue.append((x,y)) #tuple
    
    while queue:
        x,y = queue.popleft()
        
        for i in range(4):
            nx = x + dx[i]
            ny = y + dy[i]
            
            #벽
            if (nx<0 or nx>=n) or (ny<0 or ny>=m):
                continue
            
            #괴물 존재
            if graph[nx][ny] == 0:
                continue
                
            if graph[nx][ny] == 1:
                graph[nx][ny] = graph[x][y] + 1
                queue.append((nx,ny))
                
    return graph[n-1][m-1]




from collections import deque

n,m = map(int, input().split())

graph = []

for i in range(n):
    graph.append(list(map(int,input())))

# 상 하 좌 우 네가지 방향 정의
dx = [-1,1,0,0]
dy = [0, 0 , -1, 1]

print(bfs(0,0))

# %%
#타겟 넘버
def dfs(nums, i, n, t):
    ret = 0
    if i==len(nums):
        if n==t: return 1
        else: return 0
    ret += dfs(nums, i+1, n+nums[i], t)
    ret += dfs(nums, i+1, n-nums[i], t)
    return ret

def solution(numbers, target):
    answer = dfs(numbers, 0, 0, target)
    return answer
