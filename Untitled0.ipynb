# %%
from google.colab import drive
drive.mount('/content/gdrive')

# %%
# %cd gdrive/My Drive/
# %cd Algorithm

# %%
# !git init

# %%
# !git add .
# !git commit -m 'setting git push from google colab'

# %%
git config --global user.email "youwjune@gmail.com"
git config --global user.name "wonjunYou"
